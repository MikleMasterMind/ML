# %% [markdown]
# # <img src="data:image/jpeg;base64,..." width="50"/>
#
# # Машинное обучение. ВМК МГУ

# %% [markdown]
# # Практическое задание 5: SVM
# ## Уровень: <font color='MediumSeaGreen'>**Исследовательский (Research)**</font>

# %% [markdown]
# # О формате сдачи
#
# 🔷 **<font color='plum'>При решении ноутбука используйте данный шаблон</font>**
#
#     ✅ Можно добавлять новые ячейки любых типов
#     ❌ Не нужно удалять текстовые ячейки c разметкой частей ноутбука и формулировками заданий
#
#
# 🔷 **<font color='plum'>При оценивании задач учитывается код</font>**
#
#     ✅ Задания, в которых необходим код, обычно помечаются фразами "Your code here"/"Ваш код" и аналогичными
#     ❌ Ответы на вопросы без сопутствующего кода оцениваются в 0 баллов
#     ❌ Наличе работоспособного кода в ноутбуке, если на сказано иного, обязательно
#
# 🔷 **<font color='plum'>При оценивании задач учитываются выводы</font>**
#
#     ✅ Задания, в которых необходимы выводы, обычно помечаются фразами Вывод"/"Ответ на вопрос"/"Ваш текст" и аналогичными
#     ✅ Обычно выводы подразумевают под собой текстовый ответ (можно писать markdown, latex).
#     ✅ Сопутствующие изображения, графики, таблички - приветствуются!
#     ❌ При отсутствии выводов задание не засчитается на полный балл

# %% [markdown]
# Цель данного задания:
#
# * Изучите нюансы работы модели SVM
# * Узнаете про метод, который позволяет понижать число признаков и изучите его особенности на практике
# * Научитесь корректировать выход модели SVM-классификатора, чтобы уметь получать вероятности
#
# -------
# <font color="white" style="opacity:0.2024"></font>
# <font color=DarkOrange>**Примерное время выполнения (execution time/время выполнения, если нажать run all) всех ячеек ноутбука при правильной реализации: до 10 минут </font>**

# %% [markdown]
# # Подготовка рабочей среды
#
# Сначала установим нужные нам версии библиотек. Мы гарантируем, что в данных версиях задание будет корректно отрабатывать.
#
# После установки нужных версий, **возможно,** нужно перезагрузить среду (runtime), но скорее всего вам это не понадобится
#
#
# На скачивание файла и установку понадобится не более 5 минут.
#
# <font color='OrangeRed'>**Важно!**</font>
#
# Устанавливать нужные версии нужно каждый раз, когда создается новый рантайм. Например, если вы 2 часа подряд делаете это задание, то подготовить библиотеки достаточно 1 раз. Но если вы, например, начали в понедельник, затем закрыли/выключили ноутбук, то при продолжении в среду, вам нужно будет запустить рантайм заново и следовательно заново установить библиотеки.
#
# <font color='OrangeRed'>**Важно!**</font>
# Если вы предпочитаете делать практические задания на своем личном ноутбуке, то проверьте, что вы установили рабочее окружение в [соответствии с гайдом](https://github.com/MSU-ML-COURSE/ML-COURSE-24-25/blob/main/tutorials/%D0%A2%D1%83%D1%82%D0%BE%D1%80%D0%B8%D0%B0%D0%BB%20%D0%BF%D0%BE%20%D1%83%D1%81%D1%82%D0%B0%D0%BD%D0%BE%D0%B2%D0%BA%D0%B5%20%D1%80%D0%B0%D0%B1%D0%BE%D1%87%D0%B5%D0%B3%D0%BE%20%D0%BE%D0%BA%D1%80%D1%83%D0%B6%D0%B5%D0%BD%D0%B8%D1%8F%20%D0%B2%20Python%20%D0%B4%D0%BB%D1%8F%20%D1%80%D0%B5%D1%88%D0%B5%D0%BD%D0%B8%D1%8F%20%D0%B7%D0%B0%D0%B4%D0%B0%D1%87%20(2).pdf)

# %%
# !!! Данный блок будет работать только в Google-Colab !!!
! gdown 10k8Hwn9kpK9SpK4IEj4-EaWQZqgYT5-Q
! pip install -r requirements_2024_25_for_colab_small.txt
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=10k8Hwn9kpK9SpK4IEj4-EaWQZqgYT5-Q
# To: c:\Users\Michael\3_curs\ML\hw7_svm\research\requirements_2024_25_for_colab_small.txt
#
#   0%|          | 0.00/375 [00:00<?, ?B/s]
# 100%|██████████| 375/375 [00:00<?, ?B/s]
# Requirement already satisfied: catboost==1.2.7 in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from -r requirements_2024_25_for_colab_small.txt (line 1)) (1.2.7)
# Requirement already satisfied: gdown==5.1.0 in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from -r requirements_2024_25_for_colab_small.txt (line 2)) (5.1.0)
# Requirement already satisfied: h5py==3.11.0 in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from -r requirements_2024_25_for_colab_small.txt (line 3)) (3.11.0)
# Requirement already satisfied: hyperopt==0.2.7 in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from -r requirements_2024_25_for_colab_small.txt (line 4)) (0.2.7)
# Requirement already satisfied: ipympl==0.9.4 in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from -r requirements_2024_25_for_colab_small.txt (line 5)) (0.9.4)
# Requirement already satisfied: ipywidgets==7.7.1 in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from -r requirements_2024_25_for_colab_small.txt (line 6)) (7.7.1)
# Requirement already satisfied: lightgbm==4.4.0 in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from -r requirements_2024_25_for_colab_small.txt (line 7)) (4.4.0)
# Requirement already satisfied: matplotlib==3.7.1 in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from -r requirements_2024_25_for_colab_small.txt (line 8)) (3.7.1)
# Requirement already satisfied: matplotlib-inline==0.1.7 in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from -r requirements_2024_25_for_colab_small.txt (line 9)) (0.1.7)
# Requirement already satisfied: numpy==1.26.4 in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from -r requirements_2024_25_for_colab_small.txt (line 10)) (1.26.4)
# Requirement already satisfied: pandas==2.1.4 in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from -r requirements_2024_25_for_colab_small.txt (line 11)) (2.1.4)
# Requirement already satisfied: pep8==1.7.1 in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from -r requirements_2024_25_for_colab_small.txt (line 12)) (1.7.1)
# Requirement already satisfied: plotly==5.15.0 in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from -r requirements_2024_25_for_colab_small.txt (line 13)) (5.15.0)
# Requirement already satisfied: pycodestyle==2.12.1 in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from -r requirements_2024_25_for_colab_small.txt (line 14)) (2.12.1)
# Requirement already satisfied: pytest==7.4.4 in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from -r requirements_2024_25_for_colab_small.txt (line 15)) (7.4.4)
# Requirement already satisfied: scikit-image==0.23.2 in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from -r requirements_2024_25_for_colab_small.txt (line 16)) (0.23.2)
# Requirement already satisfied: scikit-learn==1.3.2 in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from -r requirements_2024_25_for_colab_small.txt (line 17)) (1.3.2)
# Requirement already satisfied: scipy==1.13.1 in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from -r requirements_2024_25_for_colab_small.txt (line 18)) (1.13.1)
# Requirement already satisfied: seaborn==0.13.1 in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from -r requirements_2024_25_for_colab_small.txt (line 19)) (0.13.1)
# Requirement already satisfied: tqdm==4.66.5 in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from -r requirements_2024_25_for_colab_small.txt (line 20)) (4.66.5)
# Requirement already satisfied: umap-learn==0.5.6 in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from -r requirements_2024_25_for_colab_small.txt (line 21)) (0.5.6)
# Requirement already satisfied: xgboost==2.1.1 in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from -r requirements_2024_25_for_colab_small.txt (line 22)) (2.1.1)
# Requirement already satisfied: graphviz in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from catboost==1.2.7->-r requirements_2024_25_for_colab_small.txt (line 1)) (0.20.3)
# Requirement already satisfied: six in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from catboost==1.2.7->-r requirements_2024_25_for_colab_small.txt (line 1)) (1.16.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from gdown==5.1.0->-r requirements_2024_25_for_colab_small.txt (line 2)) (4.12.3)
# Requirement already satisfied: filelock in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from gdown==5.1.0->-r requirements_2024_25_for_colab_small.txt (line 2)) (3.16.1)
# Requirement already satisfied: requests[socks] in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from gdown==5.1.0->-r requirements_2024_25_for_colab_small.txt (line 2)) (2.32.3)
# Requirement already satisfied: networkx>=2.2 in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from hyperopt==0.2.7->-r requirements_2024_25_for_colab_small.txt (line 4)) (3.3)
# Requirement already satisfied: future in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from hyperopt==0.2.7->-r requirements_2024_25_for_colab_small.txt (line 4)) (1.0.0)
# Requirement already satisfied: cloudpickle in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from hyperopt==0.2.7->-r requirements_2024_25_for_colab_small.txt (line 4)) (3.0.0)
# Requirement already satisfied: py4j in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from hyperopt==0.2.7->-r requirements_2024_25_for_colab_small.txt (line 4)) (0.10.9.7)
# Requirement already satisfied: ipython-genutils in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from ipympl==0.9.4->-r requirements_2024_25_for_colab_small.txt (line 5)) (0.2.0)
# Requirement already satisfied: ipython<9 in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from ipympl==0.9.4->-r requirements_2024_25_for_colab_small.txt (line 5)) (8.27.0)
# Requirement already satisfied: pillow in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from ipympl==0.9.4->-r requirements_2024_25_for_colab_small.txt (line 5)) (10.4.0)
# Requirement already satisfied: traitlets<6 in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from ipympl==0.9.4->-r requirements_2024_25_for_colab_small.txt (line 5)) (5.14.3)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from ipywidgets==7.7.1->-r requirements_2024_25_for_colab_small.txt (line 6)) (6.29.5)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from ipywidgets==7.7.1->-r requirements_2024_25_for_colab_small.txt (line 6)) (3.6.9)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from ipywidgets==7.7.1->-r requirements_2024_25_for_colab_small.txt (line 6)) (1.1.10)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from matplotlib==3.7.1->-r requirements_2024_25_for_colab_small.txt (line 8)) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from matplotlib==3.7.1->-r requirements_2024_25_for_colab_small.txt (line 8)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from matplotlib==3.7.1->-r requirements_2024_25_for_colab_small.txt (line 8)) (4.54.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from matplotlib==3.7.1->-r requirements_2024_25_for_colab_small.txt (line 8)) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from matplotlib==3.7.1->-r requirements_2024_25_for_colab_small.txt (line 8)) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from matplotlib==3.7.1->-r requirements_2024_25_for_colab_small.txt (line 8)) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from matplotlib==3.7.1->-r requirements_2024_25_for_colab_small.txt (line 8)) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from pandas==2.1.4->-r requirements_2024_25_for_colab_small.txt (line 11)) (2024.2)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from pandas==2.1.4->-r requirements_2024_25_for_colab_small.txt (line 11)) (2024.2)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from plotly==5.15.0->-r requirements_2024_25_for_colab_small.txt (line 13)) (9.0.0)
# Requirement already satisfied: iniconfig in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from pytest==7.4.4->-r requirements_2024_25_for_colab_small.txt (line 15)) (2.0.0)
# Requirement already satisfied: pluggy<2.0,>=0.12 in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from pytest==7.4.4->-r requirements_2024_25_for_colab_small.txt (line 15)) (1.5.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc8 in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from pytest==7.4.4->-r requirements_2024_25_for_colab_small.txt (line 15)) (1.2.2)
# Requirement already satisfied: tomli>=1.0.0 in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from pytest==7.4.4->-r requirements_2024_25_for_colab_small.txt (line 15)) (2.0.1)
# Requirement already satisfied: colorama in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from pytest==7.4.4->-r requirements_2024_25_for_colab_small.txt (line 15)) (0.4.6)
# Requirement already satisfied: imageio>=2.33 in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from scikit-image==0.23.2->-r requirements_2024_25_for_colab_small.txt (line 16)) (2.35.1)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from scikit-image==0.23.2->-r requirements_2024_25_for_colab_small.txt (line 16)) (2024.9.20)
# Requirement already satisfied: lazy-loader>=0.4 in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from scikit-image==0.23.2->-r requirements_2024_25_for_colab_small.txt (line 16)) (0.4)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from scikit-learn==1.3.2->-r requirements_2024_25_for_colab_small.txt (line 17)) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from scikit-learn==1.3.2->-r requirements_2024_25_for_colab_small.txt (line 17)) (3.5.0)
# Requirement already satisfied: numba>=0.51.2 in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from umap-learn==0.5.6->-r requirements_2024_25_for_colab_small.txt (line 21)) (0.60.0)
# Requirement already satisfied: pynndescent>=0.5 in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from umap-learn==0.5.6->-r requirements_2024_25_for_colab_small.txt (line 21)) (0.5.13)
# Requirement already satisfied: comm>=0.1.1 in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.1->-r requirements_2024_25_for_colab_small.txt (line 6)) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.1->-r requirements_2024_25_for_colab_small.txt (line 6)) (1.8.5)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.1->-r requirements_2024_25_for_colab_small.txt (line 6)) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.1->-r requirements_2024_25_for_colab_small.txt (line 6)) (5.7.2)
# Requirement already satisfied: nest-asyncio in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.1->-r requirements_2024_25_for_colab_small.txt (line 6)) (1.6.0)
# Requirement already satisfied: psutil in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.1->-r requirements_2024_25_for_colab_small.txt (line 6)) (6.0.0)
# Requirement already satisfied: pyzmq>=24 in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.1->-r requirements_2024_25_for_colab_small.txt (line 6)) (26.2.0)
# Requirement already satisfied: tornado>=6.1 in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.1->-r requirements_2024_25_for_colab_small.txt (line 6)) (6.4.1)
# Requirement already satisfied: decorator in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from ipython<9->ipympl==0.9.4->-r requirements_2024_25_for_colab_small.txt (line 5)) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from ipython<9->ipympl==0.9.4->-r requirements_2024_25_for_colab_small.txt (line 5)) (0.19.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from ipython<9->ipympl==0.9.4->-r requirements_2024_25_for_colab_small.txt (line 5)) (3.0.47)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from ipython<9->ipympl==0.9.4->-r requirements_2024_25_for_colab_small.txt (line 5)) (2.18.0)
# Requirement already satisfied: stack-data in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from ipython<9->ipympl==0.9.4->-r requirements_2024_25_for_colab_small.txt (line 5)) (0.6.2)
# Requirement already satisfied: typing-extensions>=4.6 in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from ipython<9->ipympl==0.9.4->-r requirements_2024_25_for_colab_small.txt (line 5)) (4.12.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from numba>=0.51.2->umap-learn==0.5.6->-r requirements_2024_25_for_colab_small.txt (line 21)) (0.43.0)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r requirements_2024_25_for_colab_small.txt (line 6)) (7.2.2)
# Requirement already satisfied: soupsieve>1.2 in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from beautifulsoup4->gdown==5.1.0->-r requirements_2024_25_for_colab_small.txt (line 2)) (2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from requests[socks]->gdown==5.1.0->-r requirements_2024_25_for_colab_small.txt (line 2)) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from requests[socks]->gdown==5.1.0->-r requirements_2024_25_for_colab_small.txt (line 2)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from requests[socks]->gdown==5.1.0->-r requirements_2024_25_for_colab_small.txt (line 2)) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from requests[socks]->gdown==5.1.0->-r requirements_2024_25_for_colab_small.txt (line 2)) (2024.8.30)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from requests[socks]->gdown==5.1.0->-r requirements_2024_25_for_colab_small.txt (line 2)) (1.7.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from jedi>=0.16->ipython<9->ipympl==0.9.4->-r requirements_2024_25_for_colab_small.txt (line 5)) (0.8.4)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.5.1->ipywidgets==7.7.1->-r requirements_2024_25_for_colab_small.txt (line 6)) (4.3.6)
# Requirement already satisfied: pywin32>=300 in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.5.1->ipywidgets==7.7.1->-r requirements_2024_25_for_colab_small.txt (line 6)) (306)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r requirements_2024_25_for_colab_small.txt (line 6)) (2.14.2)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r requirements_2024_25_for_colab_small.txt (line 6)) (2.27.3)
# Requirement already satisfied: jupyterlab<4.3,>=4.2.0 in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r requirements_2024_25_for_colab_small.txt (line 6)) (4.2.5)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r requirements_2024_25_for_colab_small.txt (line 6)) (0.2.4)
# Requirement already satisfied: wcwidth in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython<9->ipympl==0.9.4->-r requirements_2024_25_for_colab_small.txt (line 5)) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from stack-data->ipython<9->ipympl==0.9.4->-r requirements_2024_25_for_colab_small.txt (line 5)) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from stack-data->ipython<9->ipympl==0.9.4->-r requirements_2024_25_for_colab_small.txt (line 5)) (2.4.1)
# Requirement already satisfied: pure-eval in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from stack-data->ipython<9->ipympl==0.9.4->-r requirements_2024_25_for_colab_small.txt (line 5)) (0.2.3)
# Requirement already satisfied: anyio>=3.1.0 in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r requirements_2024_25_for_colab_small.txt (line 6)) (4.6.0)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r requirements_2024_25_for_colab_small.txt (line 6)) (23.1.0)
# Requirement already satisfied: jinja2>=3.0.3 in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r requirements_2024_25_for_colab_small.txt (line 6)) (3.1.4)
# Requirement already satisfied: jupyter-events>=0.9.0 in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r requirements_2024_25_for_colab_small.txt (line 6)) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r requirements_2024_25_for_colab_small.txt (line 6)) (0.5.3)
# Requirement already satisfied: nbconvert>=6.4.4 in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r requirements_2024_25_for_colab_small.txt (line 6)) (7.16.4)
# Requirement already satisfied: nbformat>=5.3.0 in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r requirements_2024_25_for_colab_small.txt (line 6)) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r requirements_2024_25_for_colab_small.txt (line 6)) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r requirements_2024_25_for_colab_small.txt (line 6)) (0.21.0)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r requirements_2024_25_for_colab_small.txt (line 6)) (2.0.13)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r requirements_2024_25_for_colab_small.txt (line 6)) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r requirements_2024_25_for_colab_small.txt (line 6)) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r requirements_2024_25_for_colab_small.txt (line 6)) (1.8.0)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r requirements_2024_25_for_colab_small.txt (line 6)) (2.0.4)
# Requirement already satisfied: httpx>=0.25.0 in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r requirements_2024_25_for_colab_small.txt (line 6)) (0.27.2)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r requirements_2024_25_for_colab_small.txt (line 6)) (2.2.5)
# Requirement already satisfied: setuptools>=40.1.0 in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r requirements_2024_25_for_colab_small.txt (line 6)) (74.1.2)
# Requirement already satisfied: babel>=2.10 in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r requirements_2024_25_for_colab_small.txt (line 6)) (2.14.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r requirements_2024_25_for_colab_small.txt (line 6)) (0.9.25)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r requirements_2024_25_for_colab_small.txt (line 6)) (4.23.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r requirements_2024_25_for_colab_small.txt (line 6)) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r requirements_2024_25_for_colab_small.txt (line 6)) (21.2.0)
# Requirement already satisfied: httpcore==1.* in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from httpx>=0.25.0->jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r requirements_2024_25_for_colab_small.txt (line 6)) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r requirements_2024_25_for_colab_small.txt (line 6)) (0.14.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from jinja2>=3.0.3->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r requirements_2024_25_for_colab_small.txt (line 6)) (2.1.5)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r requirements_2024_25_for_colab_small.txt (line 6)) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r requirements_2024_25_for_colab_small.txt (line 6)) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r requirements_2024_25_for_colab_small.txt (line 6)) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r requirements_2024_25_for_colab_small.txt (line 6)) (0.20.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r requirements_2024_25_for_colab_small.txt (line 6)) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r requirements_2024_25_for_colab_small.txt (line 6)) (6.0.2)
# Requirement already satisfied: rfc3339-validator in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r requirements_2024_25_for_colab_small.txt (line 6)) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r requirements_2024_25_for_colab_small.txt (line 6)) (0.1.1)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r requirements_2024_25_for_colab_small.txt (line 6)) (6.1.0)
# Requirement already satisfied: defusedxml in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r requirements_2024_25_for_colab_small.txt (line 6)) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r requirements_2024_25_for_colab_small.txt (line 6)) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r requirements_2024_25_for_colab_small.txt (line 6)) (3.0.2)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r requirements_2024_25_for_colab_small.txt (line 6)) (0.10.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r requirements_2024_25_for_colab_small.txt (line 6)) (1.5.0)
# Requirement already satisfied: tinycss2 in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r requirements_2024_25_for_colab_small.txt (line 6)) (1.3.0)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r requirements_2024_25_for_colab_small.txt (line 6)) (2.20.0)
# Requirement already satisfied: webencodings in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from bleach!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r requirements_2024_25_for_colab_small.txt (line 6)) (0.5.1)
# Requirement already satisfied: fqdn in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r requirements_2024_25_for_colab_small.txt (line 6)) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r requirements_2024_25_for_colab_small.txt (line 6)) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r requirements_2024_25_for_colab_small.txt (line 6)) (3.0.0)
# Requirement already satisfied: uri-template in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r requirements_2024_25_for_colab_small.txt (line 6)) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r requirements_2024_25_for_colab_small.txt (line 6)) (24.8.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r requirements_2024_25_for_colab_small.txt (line 6)) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r requirements_2024_25_for_colab_small.txt (line 6)) (2.22)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r requirements_2024_25_for_colab_small.txt (line 6)) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in c:\users\michael\anaconda3\envs\conda_env_24_251\lib\site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r requirements_2024_25_for_colab_small.txt (line 6)) (2.9.0.20240906)

# %% [markdown]
# Проверим версию библиотеки:

# %%
import catboost
assert(catboost.__version__ == '1.2.7')

# %% [markdown]
# Теперь можно приступать к выполнению задания! :)

# %% [markdown]
# -----------
# <font color="white" style="opacity:0.2023"></font>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

from copy import copy

# %% [markdown]
# Если Вы дальтоник, то можете воспользоваться готовой colormap из matplotlib (или найти свою):
# ```
# plt.style.use('tableau-colorblind10')
# ```

# %%
from matplotlib.colors import ListedColormap

from sklearn.svm import LinearSVC, SVC
from sklearn.decomposition import PCA
from sklearn.model_selection import cross_val_score, cross_val_predict, cross_validate, train_test_split
from sklearn.metrics import make_scorer, accuracy_score, roc_auc_score
from sklearn.datasets import make_blobs, make_circles, make_moons

# %%
def make_moons_cls(size=1000, d=2):
    X, y = make_moons(n_samples=size, noise=0.15)
    if d > 2:
        X = np.concatenate((X, np.random.normal(size=(size, d-2))), axis=1)
    return X, y

def make_circles_cls():
    X, y = make_circles()

def generate_data_with_imb_classes(size1=100, size2=10):
    X = np.r_[(
        np.random.normal(loc=1.0, size=(size1, 2)),
        np.random.normal(loc=0.5, size=(size2, 2))
    )]

    y = np.ones(len(X))
    y[-size2:] = 0
    return X, y

# %%
def plot_separating_surface(X, y, cls, view_support=False, title=''):
    x_min = min(X[:, 0]) - 0.1
    x_max = max(X[:, 0]) + 0.1
    y_min = min(X[:, 1]) - 0.1
    y_max = max(X[:, 1]) + 0.1
    h = 0.005
    cm = plt.cm.RdBu
    cm_bright = ListedColormap(['#FF0000', '#0000FF'])

    xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                             np.arange(y_min, y_max, h))
    Z = cls.predict(np.c_[xx.ravel(), yy.ravel()])

    plt.figure(figsize=(10, 10))
    if title:
        plt.title(title)
    plt.scatter(X[:, 0], X[:, 1], c=y, edgecolors='k', s=40, cmap=cm_bright)
    if view_support:
        plt.scatter(X[cls.support_, 0], X[cls.support_, 1],
                    c=y[cls.support_], edgecolors='k', s=150, cmap=cm_bright)
    Z = Z.reshape(xx.shape)
    plt.xticks(())
    plt.yticks(())
    plt.contourf(xx, yy, Z, cmap=cm, alpha=.3)
    plt.show()

# %% [markdown]
# # Загрузка данных

# %%
import gdown
gdown.download_folder('https://drive.google.com/drive/folders/1bp39_Jj0edo1lzxZ3DIoChsOVy5DVi1R?usp=sharing')
# Out:
# Retrieving folder contents
# Retrieving folder 1tv605hGxdQtd4zC787DbcRF0312gDeK_ imbalanced
# Processing file 14zd2xHDChSHtMWQ_TUzM8td7s8gzCO2u X_imb_test.npz.npy
# Processing file 1Qed066d3gUsUOZiUZu6aCrIH9f0yWKSc X_imb.npz.npy
# Processing file 1uD87Xbh4MMBBn5fsScrknI54SINIqory y_imb_test.npz.npy
# Processing file 1RR2VU_6WJMLo88k8C1VzBwb2Ibnz1yJf y_imb.npz.npy
# Retrieving folder 1uoI6vZWwIII1jd2k5TtsZTJ3JOkK0G6O public
# Processing file 1Win7ZtHLHEbDtX6x6O7vBJHwJviQxbp5 cX_test.npy
# Processing file 1MowPnLFAMEjjcAjDA4skE4OUFdmaiSY6 cX_train.npy
# Processing file 1VYA4N5wCQhwteQSZkDogFTha2xRv0FgW cy_train.npy
# Retrieving folder contents completed
# Building directory structure
# Building directory structure completed
# Downloading...
# From: https://drive.google.com/uc?id=14zd2xHDChSHtMWQ_TUzM8td7s8gzCO2u
# To: c:\Users\Michael\3_curs\ML\hw7_svm\research\05-SVM\imbalanced\X_imb_test.npz.npy
# 100%|██████████| 2.05k/2.05k [00:00<00:00, 2.05MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1Qed066d3gUsUOZiUZu6aCrIH9f0yWKSc
# To: c:\Users\Michael\3_curs\ML\hw7_svm\research\05-SVM\imbalanced\X_imb.npz.npy
# 100%|██████████| 2.05k/2.05k [00:00<00:00, 2.18MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1uD87Xbh4MMBBn5fsScrknI54SINIqory
# To: c:\Users\Michael\3_curs\ML\hw7_svm\research\05-SVM\imbalanced\y_imb_test.npz.npy
# 100%|██████████| 1.09k/1.09k [00:00<?, ?B/s]
# Downloading...
# From: https://drive.google.com/uc?id=1RR2VU_6WJMLo88k8C1VzBwb2Ibnz1yJf
# To: c:\Users\Michael\3_curs\ML\hw7_svm\research\05-SVM\imbalanced\y_imb.npz.npy
# 100%|██████████| 1.09k/1.09k [00:00<?, ?B/s]
# Downloading...
# From: https://drive.google.com/uc?id=1Win7ZtHLHEbDtX6x6O7vBJHwJviQxbp5
# To: c:\Users\Michael\3_curs\ML\hw7_svm\research\05-SVM\public\cX_test.npy
# 100%|██████████| 8.13k/8.13k [00:00<00:00, 4.07MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1MowPnLFAMEjjcAjDA4skE4OUFdmaiSY6
# To: c:\Users\Michael\3_curs\ML\hw7_svm\research\05-SVM\public\cX_train.npy
# 100%|██████████| 32.1k/32.1k [00:00<00:00, 1.35MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1VYA4N5wCQhwteQSZkDogFTha2xRv0FgW
# To: c:\Users\Michael\3_curs\ML\hw7_svm\research\05-SVM\public\cy_train.npy
# 100%|██████████| 6.53k/6.53k [00:00<00:00, 2.18MB/s]
# Download completed
# ['c:\\Users\\Michael\\3_curs\\ML\\hw7_svm\\research\\05-SVM\\imbalanced\\X_imb_test.npz.npy',
#  'c:\\Users\\Michael\\3_curs\\ML\\hw7_svm\\research\\05-SVM\\imbalanced\\X_imb.npz.npy',
#  'c:\\Users\\Michael\\3_curs\\ML\\hw7_svm\\research\\05-SVM\\imbalanced\\y_imb_test.npz.npy',
#  'c:\\Users\\Michael\\3_curs\\ML\\hw7_svm\\research\\05-SVM\\imbalanced\\y_imb.npz.npy',
#  'c:\\Users\\Michael\\3_curs\\ML\\hw7_svm\\research\\05-SVM\\public\\cX_test.npy',
#  'c:\\Users\\Michael\\3_curs\\ML\\hw7_svm\\research\\05-SVM\\public\\cX_train.npy',
#  'c:\\Users\\Michael\\3_curs\\ML\\hw7_svm\\research\\05-SVM\\public\\cy_train.npy']

# %% [markdown]
# Перед выполнение данного ноутбука рекомендуем просмотреть базовый ноутбук по SVM

# %% [markdown]
# # Форма разделяющей поверхности для несбалансированных классов

# %% [markdown]
# Формы разделяющих поверхностей могут быть вариативными для нелинейного случая. Иногда, выбранная форма поверхности может плохо подходить для целевого распределения объектов. Особенно это может быть заметно, если соотношение  классов в обучении отличается от тестового. Такое свойственно медицинским данным, где в обучающих данных часто наблюдается перекос в сторону больных, так как именно их данные чаще собираются.
#
# Давайте обучим SVC на несбалансированных данных и построим разделяющую поверхность для тестовой выборки с другим соотношением классов.

# %%
X_distr1 = np.load('05-SVM/imbalanced/X_imb.npz.npy')
y_distr1 = np.load('05-SVM/imbalanced/y_imb.npz.npy')
X_distr2 = np.load('05-SVM/imbalanced/X_imb_test.npz.npy')
y_distr2 = np.load('05-SVM/imbalanced/y_imb_test.npz.npy')

# %%
# Модель с дефолтными параметрами, которую Вам предстоит улучшить
base_model = SVC()
base_model.fit(X_distr1, y_distr1)
plot_separating_surface(X_distr2, y_distr2, base_model)

# %% [markdown]
# -----------
# <font color="white" style="opacity:0.2023"></font>

# %% [markdown]
# Так как синих объектов было существенно больше в обучении, разделяющая поверхность отнесла к этому классу большую часть пространства около границы классов. При этом, из-за возросшего количества красных объектов в тестовой выборке, многие из них стали ошибочно относиться к другому классу.
#
# Один из способов исправить эту проблему - это повлиять на форму поверхности с помощью задания весов классов, которые задаются через параметр class_weight в sklearn.svm.SVC. Особенно это может быть полезно в задачах, где известно, что распределение классов в обучающей выборке отличается от реального.

# %% [markdown]
# ## <font color='DarkOrange'>**Задание 1 [2 баллa]**</font>
#
# В данном задании вам будет дана выборка с несбалансированными данными. Кроме того, дана вторая выборка,
# в которой классы имеют то же распределение, но классы имеют другое соотношение.  **Вам нужно построить различные rbf-модели, меняя параметры весов классов и визуализировать разделяющие поверхности. Попробуйте улучшить
# качество на второй выборке (X_distr2, y_distr2), обучаясь только на первой (X_distr1, y_distr1) меняя параметры весов классов относительно дефолтных: class_weight={1: 1.0, 0: 1.0}. В качестве метрики, которую нужно оптимизировать нужно использовать accuracy на (X_distr2, y_dist2).**

# %%
from itertools import product

# %%
w1_best, w2_best = None, None
accuracy_best = None
grid = [0.01, 0.1, 0.5, 1.0, 5, 10, 100, 1000]
for w1, w2 in product(grid, grid):
    svc_cls = SVC(C=1.0, class_weight={1: w1, 0: w2})
    svc_cls.fit(X_distr1, y_distr1)
    pred = svc_cls.predict(X_distr2)
    accuracy = accuracy_score(y_distr2, pred)
    if accuracy_best is None or accuracy > accuracy_best:
        accuracy_best, w1_best, w2_best = accuracy, w1, w2


print(f'Weight1: {w1_best}')
print(f'Weight2: {w2_best}')
print(f'Best accuracy: {accuracy_best}')
# Out:
# Weight1: 0.1
# Weight2: 5
# Best accuracy: 0.9666666666666667

# %%
svc_best = SVC(C=1.0, class_weight={1: w1_best, 0: w2_best})
svc_best.fit(X_distr1, y_distr1)
plot_separating_surface(X_distr2, y_distr2, svc_best)

# %%
print('best accuracy:', accuracy_score(y_distr2, svc_best.predict(X_distr2)))
# Out:
# best accuracy: 0.9666666666666667

# %% [markdown]
# # Ограничения SVM

# %% [markdown]
# В предыдущих заданиях мы убедились в мощности и гибкости моделей SVM. Теперь ответим на вопрос, насколько реально обучить модель SVM на выборках большого размера или с большим числом признаков.
#
# ## <font color='DarkOrange'>**Задание 2 [2 баллa]**</font>
#
#    Нужно провести два эксперимента. В первом перебирать размер выборки
#     и для каждого запуска посчитать реальное время обучения модели. При этом
#     делить выборку на обучение и тестирование не нужно. Также качество обученной модели в данном эксперименте не имеет значение. Размеры выборки предлагается перебирать в диапазоне range(1000, 10001, 1000) с использованием generate_data_with_balanced_classes(size=n).
#
#    Необходимо сравнить время обучения SVM с логистической регрессией. Для этого
#     замеры повторите также для модели sklearn.linear_model.LogisticRegression. Время обучения одной модели замеряйте
#     с помощью стандартной библиотеки time (пример в ячейке ниже).
#
# Вы можете поставить эксперименты и с большими выборками, чем предлагается в задании (сгенерировать их),
# тогда эффект должен быть виден еще сильнее.
#
# <font color='OrangeRed'>**Внимание!**</font> во время замеров времени работы, отключите сторонние процессы, занимающие CPU, иначе замеры времени работы окажутся некорректными. Помните, что времени работы в зависимости от числа данных и признаков должно меняться монотонно, без ступенчатых изменений (за исключением небольшого шума).

# %%
# Как замерять время
import time
time_start = time.time()
time.sleep(1) # Вместо этой команды - запуск замеряемого алгоритма
print("Время работы:", time.time() - time_start)
# Out:
# Время работы: 1.0047047138214111

# %%
def generate_data_with_balanced_classes(size=500, d=2, noise_scale=0.1):
    X = np.random.normal(size=(size*2, d))
    mask = X[:, 1] ** 2 > X[:, 0] - 0.1 + np.random.normal(scale=noise_scale)
    y = np.ones(len(X))
    y[mask] = 0
    return X, y

# %%
from sklearn.linear_model import LogisticRegression

for n in range(1000, 10001, 1000):
    print("n:", n)
    X, y = generate_data_with_balanced_classes(size=n)
    svc_model = SVC()
    time_start = time.time()
    svc_model.fit(X, y)
    print("Время работы svc:", time.time() - time_start)
    logreg_model = LogisticRegression()
    time_start = time.time()
    logreg_model.fit(X, y)
    print("Время работы logistic regression:", time.time() - time_start)
# Out:
# n: 1000
# Время работы svc: 0.02203845977783203
# Время работы logistic regression: 0.006963968276977539
# n: 2000
# Время работы svc: 0.03002023696899414
# Время работы logistic regression: 0.002984762191772461
# n: 3000
# Время работы svc: 0.05499529838562012
# Время работы logistic regression: 0.008997917175292969
# n: 4000
# Время работы svc: 0.07999944686889648
# Время работы logistic regression: 0.011000633239746094
# n: 5000
# Время работы svc: 0.1269993782043457
# Время работы logistic regression: 0.012000322341918945
# n: 6000
# Время работы svc: 0.1600048542022705
# Время работы logistic regression: 0.010998725891113281
# n: 7000
# Время работы svc: 0.1929922103881836
# Время работы logistic regression: 0.013000726699829102
# n: 8000
# Время работы svc: 0.28071022033691406
# Время работы logistic regression: 0.011998414993286133
# n: 9000
# Время работы svc: 0.3260002136230469
# Время работы logistic regression: 0.012011289596557617
# n: 10000
# Время работы svc: 0.37499237060546875
# Время работы logistic regression: 0.014000892639160156

# %% [markdown]
# ## <font color='DarkOrange'>**Задание 3 [2 баллa]**</font>

# %% [markdown]
# Во втором эксперименте предлагается проделать то же самое, что и в первом эксперименте, только меняя размерность пространства признаков.
#     Для этого можете воспользоваться функцией generate_data_with_balanced_classes(dim=d). Признаки предлагается перебирать по сетке `range(10, 1001, 100)`.

# %% [markdown]
# Постройте графики времени работы в зависимости от числа объектов для SVM и логистической регрессии, сравните их и сделайте выводы.
#
# <font color='LightSteelBlue'>**Подсказка**</font> Придумывая обоснование получившимся результатам попробуйте использовать
#     вид решаемой задачи в SVM, который был дан вам на лекции.

# %%
svc_time, logisticRegression_time = [], []
dim_range = range(10, 1001, 100)

for dim in dim_range:
    print("d:", dim)
    X, y = generate_data_with_balanced_classes(d=dim)
    
    svc_model = SVC()
    time_start = time.time()
    svc_model.fit(X, y)
    scv_time_step = time.time() - time_start
    print("Время работы svc:", scv_time_step)
    svc_time.append(scv_time_step)
    
    logreg_model = LogisticRegression()
    time_start = time.time()
    logreg_model.fit(X, y)
    logisticRegression_time_step = time.time() - time_start
    print("Время работы Logistic regression:", logisticRegression_time_step)
    logisticRegression_time.append(logisticRegression_time_step)

plt.figure(figsize=(9, 6))
plt.title("Зависимость времени работы от числа объектов")
plt.grid(True)
plt.xlabel("Число объектов")
plt.ylabel("Время")
plt.plot(list(dim_range), svc_time, label="SVC")
plt.plot(list(dim_range), logisticRegression_time, label="LogReg")
plt.legend()
plt.show()
# Out:
# d: 10
# Время работы svc: 0.010007143020629883
# Время работы Logistic regression: 0.005991220474243164
# d: 110
# Время работы svc: 0.0339970588684082
# Время работы Logistic regression: 0.00799250602722168
# d: 210
# Время работы svc: 0.04900074005126953
# Время работы Logistic regression: 0.012991666793823242
# d: 310
# Время работы svc: 0.06699991226196289
# Время работы Logistic regression: 0.019992828369140625
# d: 410
# Время работы svc: 0.08800053596496582
# Время работы Logistic regression: 0.021995067596435547
# d: 510
# Время работы svc: 0.10500001907348633
# Время работы Logistic regression: 0.023993968963623047
# d: 610
# Время работы svc: 0.11899232864379883
# Время работы Logistic regression: 0.02500152587890625
# d: 710
# Время работы svc: 0.13161730766296387
# Время работы Logistic regression: 0.025007963180541992
# d: 810
# Время работы svc: 0.15600085258483887
# Время работы Logistic regression: 0.02399444580078125
# d: 910
# Время работы svc: 0.17739176750183105
# Время работы Logistic regression: 0.030946969985961914

# %% [markdown]
# <font color='MediumOrchid'>**Ваши выводы тут:**</font>
#
# Время обучения модели SVM увеличивается в сравнении с логистической регрессии.
#
# Сложность обучения svm растёт квадратично с увеличением числа объектов.
#
# Логистическая регрессия показывает линейный рост времени обучения в зависимости от числа признаков, что свидетельствует о её относительной масштабируемости по сравнению с SVM.

# %% [markdown]
# # Уменьшение размерности входа

# %% [markdown]
# Если уменьшение числа объектов сложная и зачастую невозможная задача, то
#     для понижения числа признаков существует стандартное решение. В предыдущих заданиях Вы уже сталкивались с l1-регуляризацией, которая позволяла уменьшить число признаков в задаче линейной классификации/регрессии. Однако для большинства ML-алгоритмов такой способ уменьшения числа признаков неприменим.
#
#    Зато существует стандартное для всех алгоритмов понижение размерности входа. Данный алгоритм называется Principal Component Analysis (PCA, метод главных компонент). Он находит такое линейное пространство меньшей размерности $k$ ($k << d$, где d изначальная размерность входа), проекция на которое теряет меньше всего информации. Подробнее об этом можете почитать тут https://scikit-learn.org/stable/modules/decomposition.html#pca.

# %% [markdown]
# ## <font color='DarkOrange'>**Задание 4 [2 баллa]**</font>

# %% [markdown]
#
#    **Эксперимент:** Проекция в очень малое число координат сильно "упрощает" выборку, из-за чего качество решения задачи может в итоге упасть. **В следующем эксперименте предлагается исследовать зависимость скорости работы метода и качества решения задачи при использовании понижения размерности. Требуется построить два графика:**
#
# 1. График зависимости времени работы всего цикла обучения от числа признаков $k$, которое остается после применения PCA.
# 2. График зависимости качества решения (accuracy) задачи классификации от числа признаков $k$, которое остается после применения PCA.
#
# При этом под полным циклом обучения подразумевается обучение PCA + обучение SVM. Данные для обучения: первые две координаты - "луны", а остальные координаты, случайные.
# Таким образом, без понижения размерности SVM с rbf ядром должен иметь точность близкую к 100\%. Чтобы лучше
# видеть эффект на графиках, можете менять размер генерируемой выборки. Для данных размеров $k$ рекомендуется перебирать от 10 до 500 (тогда будет видна требуемая закономерность).
#
# <font color='OrangeRed'>**Обратите внимание!**</font> Не забывайте делить выборку на обучение и валидацию в этом эксперименте (так как мы смотрим на качество, мы хотим считать его честно). При этом PCA как и любой другой алгоритм ML тоже нельзя учить на тесте. Общая схема применения PCA описана в ячейках ниже.

# %%
X_moons, y_moons = make_moons_cls(2000, 1000)

# %%
X_moons.shape
# Out:
# (2000, 1000)

# %%
plt.scatter(X_moons[:, 0], X_moons[:, 1], c=y_moons)
plt.xlabel('$x_0$')
plt.ylabel('$x_1$')
plt.show()

# %%
plt.scatter(X_moons[:, 0], X_moons[:, 2], c=y_moons)
plt.xlabel('$x_0$')
plt.ylabel('$x_2$')
plt.show()

# %%
plt.scatter(X_moons[:, 2], X_moons[:, 3], c=y_moons)
plt.xlabel('$x_2$')
plt.ylabel('$x_3$')
plt.show()

# %% [markdown]
# Казалось бы понизить размерность в этой задаче достаточно легко, нужно просто выбрать только первые две координаты. Однако из-за нелинейности разделяющей поверхности, для PCA это задача нетривиальна. Такая же ситуация наблюдается и в большинстве прикладных задач. Теперь переходите **к эксперименту** :)

# %%
# Пример правильного обучения PCA с делением на train/test
pca_model = PCA(n_components=500)

X_moons_train, X_moons_test, y_moons_train, y_moons_test = train_test_split(
    X_moons, y_moons, test_size=0.2) # делим выборку на трейн тест для оценки качества всего алгоритма

X_train_for_pca, X_train_for_svc, y_train_for_pca, y_train_for_svc = train_test_split(
    X_moons_train, y_moons_train, test_size=0.5) # делим выборку на трейн тест для оценки качества всего алгоритма

print(X_moons.shape, y_moons.shape)
print(X_moons_train.shape, y_moons_train.shape)
print(X_train_for_pca.shape, y_train_for_pca.shape)

# Учим PCA
pca_model.fit(X_train_for_pca)

# Применяем PCA
X_moons_test_transformed = pca_model.transform(X_moons_test)
X_train_for_svc_transformed = pca_model.transform(X_train_for_svc)

print(X_train_for_svc_transformed.shape)

# Учим SVC (на другой выборке чтобы не переобучиться)
svc_on_transformed = SVC(kernel='rbf')
svc_on_transformed.fit(X_train_for_svc_transformed, y_train_for_svc)

preds = svc_on_transformed.predict(X_moons_test_transformed)

print('Accuracy after PCA:', accuracy_score(preds, y_moons_test))
# Out:
# (2000, 1000) (2000,)
# (1600, 1000) (1600,)
# (800, 1000) (800,)
# (800, 500)
# Accuracy after PCA: 0.5975

# %%
time_list, accuracy_list = [], []
k_range = range(10, 501, 10)
for k in k_range:
    pca_model = PCA(n_components=k)
    
    X_moons_train, X_moons_test, y_moons_train, y_moons_test = train_test_split(X_moons, y_moons, test_size=0.2)
    X_train_for_pca, X_train_for_svc, y_train_for_pca, y_train_for_svc = train_test_split(X_moons_train, y_moons_train, test_size=0.5)
    
    start_time = time.time()
    pca_model.fit(X_train_for_pca)
    time_step = time.time() - start_time
    
    X_moons_test_transformed = pca_model.transform(X_moons_test)
    X_train_for_svc_transformed = pca_model.transform(X_train_for_svc)
    
    svc_on_transformed = SVC(kernel='rbf')
    start_time = time.time()
    svc_on_transformed.fit(X_train_for_svc_transformed, y_train_for_svc)
    time_step += time.time() - start_time
    
    pred = svc_on_transformed.predict(X_moons_test_transformed)
    
    time_list.append(time_step)
    accuracy_list.append(accuracy_score(pred, y_moons_test))

# %%
plt.figure(figsize=(12, 5))
plt.title("График зависимости времени работы всего цикла обучения от числа признаков k, которое остается после применения PCA.", fontsize=10)
plt.grid(True)
plt.xlabel("k")
plt.ylabel("time")
plt.plot(list(k_range), time_list, color='red')
plt.show()

# %%
plt.figure(figsize=(12, 5))
plt.title("График зависимости качества решения (accuracy) задачи классификации от числа признаков k, которое остается после применения PCA.", fontsize=10)
plt.grid(True)
plt.xlabel("k")
plt.ylabel("accuracy")
plt.plot(list(k_range), accuracy_list, color='red')
plt.show()

# %% [markdown]
# Опишите в выводе как ведет себя качество решения задачи и время работы в зависимости от числа компонент в PCA.

# %% [markdown]
# <font color='MediumOrchid'>**Ваши выводы тут:**</font>
#
# Время обучения с увеличением числа признаков растёт. Качество - падает.

# %% [markdown]
# # Калибровка вероятностей

# %% [markdown]
# Иногда в задаче классификации важно знать уверенность отнесения к тому или иному классу. В SVM за это отвечает параметр отступа (margin), который можно посчитать, используя model.decision_function(X). Именно отступ до разделяющей кривой пытается максимизироавть модель во время обучения. Однако по нему сложно утверждать с какой вероятностью объект относится к тому или иному классу.
#
# Чтобы это понять давайте построим следующую кривую:
# 1) нормализуем отступы так, чтобы они лежали в диапазоне от 0 до 1;
#
# 2) разделим все объекты на бины по нормализованному оступу (например на [0, 0.1), [0.1, 0.2)...);
#
# 3) для каждого бина построим точку с координатой x - равной среднему значению нормализованного оступа внутри бина, и с координатой y - равной доле объектов класса 1 внутри бина.
#
# Заметим теперь, что если бы нормализованный отступ приблизительно равнялся вероятности отнесения к классу, то бину [x, x + 0.1) должна была бы соответствовать точка с координатой Х принадлежащей [x, x + 0.1) и координатой Y в том же диапазоне. Таким образом, чем лучше скоры модели показывают вероятность отнесения к классу 1, тем больше калибровочная кривая похожа на прямую из точки (0, 0) в (1, 1).
#
# Кроме того построим аналогично кривую для логистической регрессии, взяв вместо нормализованного отступа - вероятность отнесения к первому классу через predict_proba. Так как логистическая регрессия оптимизирует LogLoss и её выходом уже являются вероятности отнесения к классам, будем ожидать что её кривая хорошо ляжет на прямую из (0, 0) в (1, 1).

# %%
from sklearn.datasets import make_classification
from sklearn.calibration import calibration_curve
from sklearn.linear_model import LogisticRegression

# %%
from sklearn.model_selection import train_test_split

# generate 2 class dataset
X, y = make_classification(n_samples=5000, n_classes=2, weights=[1,1], random_state=1)
# split into train/test sets
trainX, testX, trainy, testy = train_test_split(X, y, test_size=0.5, random_state=2)
# fit a model
model = SVC()
model.fit(trainX, trainy)
# predict probabilities
probs = model.decision_function(testX)

# reliability diagram
fop, mpv = calibration_curve(testy, probs, n_bins=10, normalize=True)
# plot perfectly calibrated
# plot model reliability
plt.plot(mpv, fop, marker='.', label='SVC')
plt.xlabel('classifier score')
plt.ylabel('[label=1] ratio')

logistic_model = LogisticRegression()
logistic_model.fit(trainX, trainy)

logistic_probs = logistic_model.predict_proba(testX)[:, 1]

# reliability diagram
log_fop, log_mpv = calibration_curve(testy, logistic_probs, n_bins=10, normalize=True)
# plot perfectly calibrated
# plot model reliability
plt.plot(log_mpv, log_fop, marker='.', label='logistic')
plt.plot([0, 1], [0, 1], linestyle='--', label='ideal')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 14
#      11 probs = model.decision_function(testX)
#      13 # reliability diagram
# ---> 14 fop, mpv = calibration_curve(testy, probs, n_bins=10, normalize=True)
#      15 # plot perfectly calibrated
#      16 # plot model reliability
#      17 plt.plot(mpv, fop, marker='.', label='SVC')
#
# File c:\Users\Michael\anaconda3\envs\conda_env_24_251\lib\site-packages\sklearn\utils\_param_validation.py:192, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     189 func_sig = signature(func)
#     191 # Map *args/**kwargs to the function signature
# --> 192 params = func_sig.bind(*args, **kwargs)
#     193 params.apply_defaults()
#     195 # ignore self/cls and positional/keyword markers
#
# File c:\Users\Michael\anaconda3\envs\conda_env_24_251\lib\inspect.py:3186, in Signature.bind(self, *args, **kwargs)
#    3181 def bind(self, /, *args, **kwargs):
#    3182     """Get a BoundArguments object, that maps the passed `args`
#    3183     and `kwargs` to the function's signature.  Raises `TypeError`
#    3184     if the passed arguments can not be bound.
#    3185     """
# -> 3186     return self._bind(args, kwargs)
#
# File c:\Users\Michael\anaconda3\envs\conda_env_24_251\lib\inspect.py:3175, in Signature._bind(self, args, kwargs, partial)
#    3173         arguments[kwargs_param.name] = kwargs
#    3174     else:
# -> 3175         raise TypeError(
#    3176             'got an unexpected keyword argument {arg!r}'.format(
#    3177                 arg=next(iter(kwargs))))
#    3179 return self._bound_arguments_cls(self, arguments)
#
# TypeError: got an unexpected keyword argument 'normalize'

# %% [markdown]
# -----------
# <font color="white" style="opacity:0.2023"></font>

# %% [markdown]
# Вот мы и увидели проблему, линия отступов не ложится на пунктирную линию, что означает что оступы не соотвествуют реальным вероятностям отнесения к тому или иному классу.
#
#    Но не всё пропало! Из отступов всё ещё можно получить вероятность отнесения к классу. Для этого существует  такая процедура как калибровка вероятностей, при которой отступ для каждого объекта преобразовывается таким образом, чтобы соответствовать вероятности класса. После такого преобразования, полученное число становится интерпретируемой мерой уверенности модели.

# %% [markdown]
# ## <font color='DarkOrange'>**Задание 5 [2 баллa]**</font>
#
# В данном задании Вам прелагается обучить логистическую регрессию на отступах модели, которая по оступу (margin) предсказывала бы класс. Именно вероятности этой калибровочной модели и будут нашими верными оценками вероятности класса для объекта:
#
# $p(y_i | x_i) = p(y_i | margin_i)$
#
# Для этого Вам потребуется написать несложный класс CalibratingLogisticRegression. И проверить что новые предсказания дают правильную калибровочную кривую

# %%
class CalibratingLogisticRegression:
    def fit(self, x, y):
        assert len(x.shape) == 1 or x.shape[1] == 1
        # Your code here

    def predict_proba(self, x):
        assert len(x.shape) == 1 or x.shape[1] == 1
        # Your code here

# %% [markdown]
# Калибровочную модель и исходную модель нельзя учить на одних и тех же данных, чтобы избежать переобучения. (распределение отступов на обучении и тестовой выборке, скорее всего очень сильно отличается)

# %%
model = SVC()
N = len(trainX) // 2
model.fit(trainX[:N], trainy[:N])

# %%
margin = ...


# Учим калибровочную модель на второй половине данных
calibrating_model = CalibratingLogisticRegression()
calibrating_model.fit(margin, trainy[N:])
prob = calibrating_model.predict_proba(margin)


# Как это выглядит на обучении
margin_sorted, probs_sorted_by_margin = zip(*sorted(zip(margin, prob)))
plt.figure(figsize=(10, 10))
plt.plot(margin, trainy[N:], 'ro')
plt.plot(margin_sorted, probs_sorted_by_margin, 'b')
plt.show()

# %%
probs = calibrating_model.predict_proba(model.decision_function(testX))
# reliability diagram
fop, mpv = calibration_curve(testy, probs, n_bins=10, normalize=True)
# plot perfectly calibrated
plt.plot([0, 1], [0, 1], linestyle='--')
# plot calibrated reliability
plt.plot(mpv, fop, marker='.')
plt.show()

# %% [markdown]
# Обратите внимание, что кривая для откалиброванных отступов должня также строиться для бинов и состоянть из n_bins точек. Если у Вас получилось кривая из трёх точек, Вы что-то сделали неправильно :)
#
# **Сделайте выводы** о полученной модели. В каких задачах калибровка вероятностей могла бы быть полезной?

# %% [markdown]
# <font color='MediumOrchid'>**Ваши выводы тут:**</font>
